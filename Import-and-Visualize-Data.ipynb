# %% [markdown]
# # Importing and Visualizing the Data

# %%
import torch
import torch.nn as nn
import numpy as np
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

import requests
import zipfile

# %%
# Determine the path where the data is stored
train_data_path = Path(r"./Data/Train")

# Create a list of all the directory paths of the image data
image_paths_list = list(train_data_path.glob("*\*.jpg"))
image_paths_list
# Out:
# [WindowsPath('Data/Train/Cube/cube_0.jpg'),
#  WindowsPath('Data/Train/Cube/cube_1.jpg'),
#  WindowsPath('Data/Train/Cube/cube_10.jpg'),
#  WindowsPath('Data/Train/Cube/cube_100.jpg'),
#  WindowsPath('Data/Train/Cube/cube_11.jpg'),
#  WindowsPath('Data/Train/Cube/cube_12.jpg'),
#  WindowsPath('Data/Train/Cube/cube_13.jpg'),
#  WindowsPath('Data/Train/Cube/cube_14.jpg'),
#  WindowsPath('Data/Train/Cube/cube_15.jpg'),
#  WindowsPath('Data/Train/Cube/cube_16.jpg'),
#  WindowsPath('Data/Train/Cube/cube_17.jpg'),
#  WindowsPath('Data/Train/Cube/cube_18.jpg'),
#  WindowsPath('Data/Train/Cube/cube_19.jpg'),
#  WindowsPath('Data/Train/Cube/cube_2.jpg'),
#  WindowsPath('Data/Train/Cube/cube_20.jpg'),
#  WindowsPath('Data/Train/Cube/cube_21.jpg'),
#  WindowsPath('Data/Train/Cube/cube_22.jpg'),
#  WindowsPath('Data/Train/Cube/cube_23.jpg'),
#  WindowsPath('Data/Train/Cube/cube_24.jpg'),
#  WindowsPath('Data/Train/Cube/cube_25.jpg'),
#  WindowsPath('Data/Train/Cube/cube_26.jpg'),
#  WindowsPath('Data/Train/Cube/cube_27.jpg'),
#  WindowsPath('Data/Train/Cube/cube_28.jpg'),
#  WindowsPath('Data/Train/Cube/cube_29.jpg'),
#  WindowsPath('Data/Train/Cube/cube_3.jpg'),
#  WindowsPath('Data/Train/Cube/cube_30.jpg'),
#  WindowsPath('Data/Train/Cube/cube_31.jpg'),
#  WindowsPath('Data/Train/Cube/cube_32.jpg'),
#  WindowsPath('Data/Train/Cube/cube_33.jpg'),
#  WindowsPath('Data/Train/Cube/cube_34.jpg'),
#  WindowsPath('Data/Train/Cube/cube_35.jpg'),
#  WindowsPath('Data/Train/Cube/cube_36.jpg'),
#  WindowsPath('Data/Train/Cube/cube_37.jpg'),
#  WindowsPath('Data/Train/Cube/cube_38.jpg'),
#  WindowsPath('Data/Train/Cube/cube_39.jpg'),
#  WindowsPath('Data/Train/Cube/cube_4.jpg'),
#  WindowsPath('Data/Train/Cube/cube_40.jpg'),
#  WindowsPath('Data/Train/Cube/cube_41.jpg'),
#  WindowsPath('Data/Train/Cube/cube_42.jpg'),
#  WindowsPath('Data/Train/Cube/cube_43.jpg'),
#  WindowsPath('Data/Train/Cube/cube_44.jpg'),
#  WindowsPath('Data/Train/Cube/cube_45.jpg'),
#  WindowsPath('Data/Train/Cube/cube_46.jpg'),
#  WindowsPath('Data/Train/Cube/cube_47.jpg'),
#  WindowsPath('Data/Train/Cube/cube_48.jpg'),
#  WindowsPath('Data/Train/Cube/cube_49.jpg'),
#  WindowsPath('Data/Train/Cube/cube_5.jpg'),
#  WindowsPath('Data/Train/Cube/cube_50.jpg'),
#  WindowsPath('Data/Train/Cube/cube_51.jpg'),
#  WindowsPath('Data/Train/Cube/cube_52.jpg'),
#  WindowsPath('Data/Train/Cube/cube_53.jpg'),
#  WindowsPath('Data/Train/Cube/cube_54.jpg'),
#  WindowsPath('Data/Train/Cube/cube_55.jpg'),
#  WindowsPath('Data/Train/Cube/cube_56.jpg'),
#  WindowsPath('Data/Train/Cube/cube_57.jpg'),
#  WindowsPath('Data/Train/Cube/cube_58.jpg'),
#  WindowsPath('Data/Train/Cube/cube_59.jpg'),
#  WindowsPath('Data/Train/Cube/cube_6.jpg'),
#  WindowsPath('Data/Train/Cube/cube_60.jpg'),
#  WindowsPath('Data/Train/Cube/cube_61.jpg'),
#  WindowsPath('Data/Train/Cube/cube_62.jpg'),
#  WindowsPath('Data/Train/Cube/cube_63.jpg'),
#  WindowsPath('Data/Train/Cube/cube_64.jpg'),
#  WindowsPath('Data/Train/Cube/cube_65.jpg'),
#  WindowsPath('Data/Train/Cube/cube_66.jpg'),
#  WindowsPath('Data/Train/Cube/cube_67.jpg'),
#  WindowsPath('Data/Train/Cube/cube_68.jpg'),
#  WindowsPath('Data/Train/Cube/cube_69.jpg'),
#  WindowsPath('Data/Train/Cube/cube_7.jpg'),
#  WindowsPath('Data/Train/Cube/cube_70.jpg'),
#  WindowsPath('Data/Train/Cube/cube_71.jpg'),
#  WindowsPath('Data/Train/Cube/cube_72.jpg'),
#  WindowsPath('Data/Train/Cube/cube_73.jpg'),
#  WindowsPath('Data/Train/Cube/cube_74.jpg'),
#  WindowsPath('Data/Train/Cube/cube_75.jpg'),
#  WindowsPath('Data/Train/Cube/cube_76.jpg'),
#  WindowsPath('Data/Train/Cube/cube_77.jpg'),
#  WindowsPath('Data/Train/Cube/cube_78.jpg'),
#  WindowsPath('Data/Train/Cube/cube_79.jpg'),
#  WindowsPath('Data/Train/Cube/cube_8.jpg'),
#  WindowsPath('Data/Train/Cube/cube_80.jpg'),
#  WindowsPath('Data/Train/Cube/cube_81.jpg'),
#  WindowsPath('Data/Train/Cube/cube_82.jpg'),
#  WindowsPath('Data/Train/Cube/cube_83.jpg'),
#  WindowsPath('Data/Train/Cube/cube_84.jpg'),
#  WindowsPath('Data/Train/Cube/cube_85.jpg'),
#  WindowsPath('Data/Train/Cube/cube_86.jpg'),
#  WindowsPath('Data/Train/Cube/cube_87.jpg'),
#  WindowsPath('Data/Train/Cube/cube_88.jpg'),
#  WindowsPath('Data/Train/Cube/cube_89.jpg'),
#  WindowsPath('Data/Train/Cube/cube_9.jpg'),
#  WindowsPath('Data/Train/Cube/cube_90.jpg'),
#  WindowsPath('Data/Train/Cube/cube_91.jpg'),
#  WindowsPath('Data/Train/Cube/cube_92.jpg'),
#  WindowsPath('Data/Train/Cube/cube_93.jpg'),
#  WindowsPath('Data/Train/Cube/cube_94.jpg'),
#  WindowsPath('Data/Train/Cube/cube_95.jpg'),
#  WindowsPath('Data/Train/Cube/cube_96.jpg'),
#  WindowsPath('Data/Train/Cube/cube_97.jpg'),
#  WindowsPath('Data/Train/Cube/cube_98.jpg'),
#  WindowsPath('Data/Train/Cube/cube_99.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_0.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_1.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_10.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_11.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_12.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_13.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_14.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_15.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_16.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_17.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_18.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_19.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_2.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_20.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_21.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_22.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_23.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_24.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_25.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_26.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_27.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_28.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_29.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_3.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_30.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_31.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_32.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_33.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_34.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_35.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_36.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_37.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_38.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_39.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_4.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_40.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_41.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_42.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_43.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_44.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_45.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_46.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_47.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_48.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_49.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_5.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_50.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_51.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_52.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_53.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_54.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_55.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_56.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_57.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_58.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_59.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_6.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_60.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_61.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_62.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_63.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_64.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_65.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_66.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_67.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_68.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_69.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_7.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_70.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_71.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_72.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_73.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_74.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_75.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_76.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_77.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_78.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_79.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_8.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_80.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_81.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_82.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_83.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_84.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_85.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_86.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_87.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_88.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_89.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_9.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_90.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_91.jpg'),
#  WindowsPath('Data/Train/Icosahedron/icosahedron_92.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_0.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_1.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_10.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_11.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_12.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_13.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_14.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_15.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_16.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_17.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_18.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_19.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_2.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_20.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_21.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_22.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_23.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_24.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_25.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_26.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_27.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_28.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_29.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_3.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_30.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_31.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_32.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_33.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_34.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_35.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_36.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_37.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_38.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_39.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_4.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_40.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_41.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_42.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_43.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_44.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_45.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_46.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_47.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_48.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_49.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_5.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_50.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_51.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_52.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_53.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_54.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_55.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_56.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_57.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_58.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_59.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_6.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_60.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_61.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_62.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_63.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_64.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_65.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_66.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_67.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_68.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_69.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_7.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_70.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_71.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_72.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_73.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_74.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_75.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_76.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_77.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_78.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_79.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_8.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_80.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_81.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_82.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_83.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_84.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_85.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_86.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_87.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_88.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_89.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_9.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_90.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_91.jpg'),
#  WindowsPath('Data/Train/Icosphere/icosphere_92.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_0.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_1.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_10.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_11.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_12.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_13.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_14.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_15.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_16.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_17.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_18.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_19.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_2.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_20.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_21.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_22.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_23.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_24.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_25.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_26.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_27.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_28.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_29.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_3.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_30.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_31.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_32.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_33.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_34.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_35.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_36.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_37.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_38.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_39.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_4.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_40.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_41.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_42.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_43.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_44.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_45.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_46.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_47.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_48.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_49.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_5.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_50.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_51.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_52.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_53.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_54.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_55.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_56.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_57.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_58.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_59.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_6.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_60.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_61.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_62.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_63.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_64.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_65.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_66.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_67.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_68.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_69.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_7.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_70.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_71.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_72.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_73.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_74.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_75.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_76.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_77.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_78.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_79.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_8.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_80.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_81.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_82.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_83.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_84.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_85.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_86.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_87.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_88.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_89.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_9.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_90.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_91.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_92.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_93.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_94.jpg'),
#  WindowsPath('Data/Train/Pyramid/pyramid_95.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_0.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_1.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_10.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_11.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_12.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_13.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_14.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_15.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_16.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_17.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_18.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_19.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_2.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_20.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_21.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_22.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_23.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_24.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_25.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_26.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_27.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_28.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_29.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_3.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_30.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_31.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_32.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_33.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_34.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_35.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_36.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_37.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_38.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_39.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_4.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_40.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_41.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_42.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_43.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_44.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_45.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_46.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_47.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_48.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_49.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_5.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_50.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_51.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_52.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_53.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_54.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_55.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_56.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_57.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_58.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_59.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_6.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_60.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_61.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_62.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_63.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_64.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_65.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_66.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_67.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_68.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_69.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_7.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_70.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_71.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_72.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_73.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_74.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_75.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_76.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_77.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_78.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_79.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_8.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_80.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_81.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_82.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_83.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_84.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_85.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_86.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_87.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_88.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_89.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_9.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_90.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_91.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_92.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_93.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_94.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_95.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_96.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_97.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_98.jpg'),
#  WindowsPath('Data/Train/Suzanne/suzanne_99.jpg'),
#  WindowsPath('Data/Train/Torus/torus_0.jpg'),
#  WindowsPath('Data/Train/Torus/torus_1.jpg'),
#  WindowsPath('Data/Train/Torus/torus_10.jpg'),
#  WindowsPath('Data/Train/Torus/torus_11.jpg'),
#  WindowsPath('Data/Train/Torus/torus_12.jpg'),
#  WindowsPath('Data/Train/Torus/torus_13.jpg'),
#  WindowsPath('Data/Train/Torus/torus_14.jpg'),
#  WindowsPath('Data/Train/Torus/torus_15.jpg'),
#  WindowsPath('Data/Train/Torus/torus_16.jpg'),
#  WindowsPath('Data/Train/Torus/torus_17.jpg'),
#  WindowsPath('Data/Train/Torus/torus_18.jpg'),
#  WindowsPath('Data/Train/Torus/torus_19.jpg'),
#  WindowsPath('Data/Train/Torus/torus_2.jpg'),
#  WindowsPath('Data/Train/Torus/torus_20.jpg'),
#  WindowsPath('Data/Train/Torus/torus_21.jpg'),
#  WindowsPath('Data/Train/Torus/torus_22.jpg'),
#  WindowsPath('Data/Train/Torus/torus_23.jpg'),
#  WindowsPath('Data/Train/Torus/torus_24.jpg'),
#  WindowsPath('Data/Train/Torus/torus_25.jpg'),
#  WindowsPath('Data/Train/Torus/torus_26.jpg'),
#  WindowsPath('Data/Train/Torus/torus_27.jpg'),
#  WindowsPath('Data/Train/Torus/torus_28.jpg'),
#  WindowsPath('Data/Train/Torus/torus_29.jpg'),
#  WindowsPath('Data/Train/Torus/torus_3.jpg'),
#  WindowsPath('Data/Train/Torus/torus_30.jpg'),
#  WindowsPath('Data/Train/Torus/torus_31.jpg'),
#  WindowsPath('Data/Train/Torus/torus_32.jpg'),
#  WindowsPath('Data/Train/Torus/torus_33.jpg'),
#  WindowsPath('Data/Train/Torus/torus_34.jpg'),
#  WindowsPath('Data/Train/Torus/torus_35.jpg'),
#  WindowsPath('Data/Train/Torus/torus_36.jpg'),
#  WindowsPath('Data/Train/Torus/torus_37.jpg'),
#  WindowsPath('Data/Train/Torus/torus_38.jpg'),
#  WindowsPath('Data/Train/Torus/torus_39.jpg'),
#  WindowsPath('Data/Train/Torus/torus_4.jpg'),
#  WindowsPath('Data/Train/Torus/torus_40.jpg'),
#  WindowsPath('Data/Train/Torus/torus_41.jpg'),
#  WindowsPath('Data/Train/Torus/torus_42.jpg'),
#  WindowsPath('Data/Train/Torus/torus_43.jpg'),
#  WindowsPath('Data/Train/Torus/torus_44.jpg'),
#  WindowsPath('Data/Train/Torus/torus_45.jpg'),
#  WindowsPath('Data/Train/Torus/torus_46.jpg'),
#  WindowsPath('Data/Train/Torus/torus_47.jpg'),
#  WindowsPath('Data/Train/Torus/torus_48.jpg'),
#  WindowsPath('Data/Train/Torus/torus_49.jpg'),
#  WindowsPath('Data/Train/Torus/torus_5.jpg'),
#  WindowsPath('Data/Train/Torus/torus_50.jpg'),
#  WindowsPath('Data/Train/Torus/torus_51.jpg'),
#  WindowsPath('Data/Train/Torus/torus_52.jpg'),
#  WindowsPath('Data/Train/Torus/torus_53.jpg'),
#  WindowsPath('Data/Train/Torus/torus_54.jpg'),
#  WindowsPath('Data/Train/Torus/torus_55.jpg'),
#  WindowsPath('Data/Train/Torus/torus_56.jpg'),
#  WindowsPath('Data/Train/Torus/torus_57.jpg'),
#  WindowsPath('Data/Train/Torus/torus_58.jpg'),
#  WindowsPath('Data/Train/Torus/torus_59.jpg'),
#  WindowsPath('Data/Train/Torus/torus_6.jpg'),
#  WindowsPath('Data/Train/Torus/torus_60.jpg'),
#  WindowsPath('Data/Train/Torus/torus_61.jpg'),
#  WindowsPath('Data/Train/Torus/torus_62.jpg'),
#  WindowsPath('Data/Train/Torus/torus_63.jpg'),
#  WindowsPath('Data/Train/Torus/torus_64.jpg'),
#  WindowsPath('Data/Train/Torus/torus_65.jpg'),
#  WindowsPath('Data/Train/Torus/torus_66.jpg'),
#  WindowsPath('Data/Train/Torus/torus_67.jpg'),
#  WindowsPath('Data/Train/Torus/torus_68.jpg'),
#  WindowsPath('Data/Train/Torus/torus_69.jpg'),
#  WindowsPath('Data/Train/Torus/torus_7.jpg'),
#  WindowsPath('Data/Train/Torus/torus_70.jpg'),
#  WindowsPath('Data/Train/Torus/torus_71.jpg'),
#  WindowsPath('Data/Train/Torus/torus_72.jpg'),
#  WindowsPath('Data/Train/Torus/torus_73.jpg'),
#  WindowsPath('Data/Train/Torus/torus_74.jpg'),
#  WindowsPath('Data/Train/Torus/torus_75.jpg'),
#  WindowsPath('Data/Train/Torus/torus_76.jpg'),
#  WindowsPath('Data/Train/Torus/torus_77.jpg'),
#  WindowsPath('Data/Train/Torus/torus_78.jpg'),
#  WindowsPath('Data/Train/Torus/torus_79.jpg'),
#  WindowsPath('Data/Train/Torus/torus_8.jpg'),
#  WindowsPath('Data/Train/Torus/torus_80.jpg'),
#  WindowsPath('Data/Train/Torus/torus_81.jpg'),
#  WindowsPath('Data/Train/Torus/torus_82.jpg'),
#  WindowsPath('Data/Train/Torus/torus_83.jpg'),
#  WindowsPath('Data/Train/Torus/torus_84.jpg'),
#  WindowsPath('Data/Train/Torus/torus_85.jpg'),
#  WindowsPath('Data/Train/Torus/torus_86.jpg'),
#  WindowsPath('Data/Train/Torus/torus_87.jpg'),
#  WindowsPath('Data/Train/Torus/torus_88.jpg'),
#  WindowsPath('Data/Train/Torus/torus_89.jpg'),
#  WindowsPath('Data/Train/Torus/torus_9.jpg'),
#  WindowsPath('Data/Train/Torus/torus_90.jpg'),
#  WindowsPath('Data/Train/Torus/torus_91.jpg'),
#  WindowsPath('Data/Train/Torus/torus_92.jpg'),
#  WindowsPath('Data/Train/Torus/torus_93.jpg'),
#  WindowsPath('Data/Train/Torus/torus_94.jpg'),
#  WindowsPath('Data/Train/Torus/torus_95.jpg'),
#  WindowsPath('Data/Train/Torus/torus_96.jpg'),
#  WindowsPath('Data/Train/Torus/torus_97.jpg')]

# %%
# Open a random image with PIL
imgn = Image.open(image_paths_list[42])
imgn
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
# Define the data-transformer to convert the image data into PyTorch Tensors of a specified dimension
data_transformer = transforms.Compose([
    transforms.Resize(size=(256,256)), #Resize the image to 256x256
    transforms.ToTensor()
])
# Transform the previous random image to a Tensor and visualize the reduction of the quality
Tensor_imgn = data_transformer(imgn)
plt.axis(False)
plt.imshow(Tensor_imgn.permute(1, 2, 0)) # The shape of the Tensor has to be changed as PyTorch has (C,H,W), while plt requires (H, W, C)

# %%
# Compare both next to each other:
fig, ax = plt.subplots(1,2, figsize=(10, 5))
# Original Image
ax[0].title.set_text("Original Image")
ax[0].axis(False)
ax[0].imshow(imgn)
# Reduced Image
ax[1].title.set_text("Reduced Image")
ax[1].axis(False)
ax[1].imshow(Tensor_imgn.permute(1, 2, 0))

# %%
# Create the training data
train_data = datasets.ImageFolder(root=r".\Data\Train", transform=data_transformer, target_transform=None)

# %%
# The classes of the training data are simply the folders
train_data.classes
# Out:
# ['Cube', 'Icosahedron', 'Icosphere', 'Pyramid', 'Suzanne', 'Torus']

# %%
# These classes are also assigned to indicies:
train_data.class_to_idx
# Out:
# {'Cube': 0,
#  'Icosahedron': 1,
#  'Icosphere': 2,
#  'Pyramid': 3,
#  'Suzanne': 4,
#  'Torus': 5}

# %%
# Visualize an example of the training data
plt.imshow(train_data[42][0].permute(1, 2, 0))

# %%
# Create a train DataLoader:
batch_size = 32
train_dataloader = DataLoader(dataset=train_data, batch_size=batch_size,shuffle=True)

# %%
# Check the batch size:
train_dataloader.batch_size
# Out:
# 32

# %%
len(train_dataloader)
# Out:
# 19

# %%
iter_train = iter(train_dataloader)

# %%
test1 = next(iter_train)

# %%
test2 = next(iter_train)

# %%
type(iter_train)
# Out:
# torch.utils.data.dataloader._SingleProcessDataLoaderIter

# %%
test2[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
# Compare both next to each other:
fig, ax = plt.subplots(1,2, figsize=(10, 5))
# Original Image
ax[0].title.set_text("Test1")
ax[0].axis(False)
ax[0].imshow(test1[0][0].permute(1, 2, 0))
# Reduced Image
ax[1].title.set_text("Test2")
ax[1].axis(False)
ax[1].imshow(test2[0][0].permute(1, 2, 0))
