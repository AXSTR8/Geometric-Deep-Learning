# %% [markdown]
# # Importing and Visualizing the Data

# %%
import torch
import numpy as np
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

import requests
import zipfile

# %%
# Determine the path where the data is stored
data_path = Path(r"./Data")

# Create a list of all the directory paths of the image data
image_paths_list = list(data_path.glob("*\*.jpg"))
image_paths_list
# Out:
# [WindowsPath('Data/Cube/cube_0.jpg'),
#  WindowsPath('Data/Cube/cube_1.jpg'),
#  WindowsPath('Data/Cube/cube_10.jpg'),
#  WindowsPath('Data/Cube/cube_11.jpg'),
#  WindowsPath('Data/Cube/cube_12.jpg'),
#  WindowsPath('Data/Cube/cube_13.jpg'),
#  WindowsPath('Data/Cube/cube_14.jpg'),
#  WindowsPath('Data/Cube/cube_15.jpg'),
#  WindowsPath('Data/Cube/cube_16.jpg'),
#  WindowsPath('Data/Cube/cube_17.jpg'),
#  WindowsPath('Data/Cube/cube_18.jpg'),
#  WindowsPath('Data/Cube/cube_19.jpg'),
#  WindowsPath('Data/Cube/cube_2.jpg'),
#  WindowsPath('Data/Cube/cube_20.jpg'),
#  WindowsPath('Data/Cube/cube_21.jpg'),
#  WindowsPath('Data/Cube/cube_22.jpg'),
#  WindowsPath('Data/Cube/cube_23.jpg'),
#  WindowsPath('Data/Cube/cube_24.jpg'),
#  WindowsPath('Data/Cube/cube_25.jpg'),
#  WindowsPath('Data/Cube/cube_26.jpg'),
#  WindowsPath('Data/Cube/cube_27.jpg'),
#  WindowsPath('Data/Cube/cube_28.jpg'),
#  WindowsPath('Data/Cube/cube_29.jpg'),
#  WindowsPath('Data/Cube/cube_3.jpg'),
#  WindowsPath('Data/Cube/cube_30.jpg'),
#  WindowsPath('Data/Cube/cube_31.jpg'),
#  WindowsPath('Data/Cube/cube_32.jpg'),
#  WindowsPath('Data/Cube/cube_33.jpg'),
#  WindowsPath('Data/Cube/cube_34.jpg'),
#  WindowsPath('Data/Cube/cube_35.jpg'),
#  WindowsPath('Data/Cube/cube_36.jpg'),
#  WindowsPath('Data/Cube/cube_37.jpg'),
#  WindowsPath('Data/Cube/cube_38.jpg'),
#  WindowsPath('Data/Cube/cube_39.jpg'),
#  WindowsPath('Data/Cube/cube_4.jpg'),
#  WindowsPath('Data/Cube/cube_40.jpg'),
#  WindowsPath('Data/Cube/cube_41.jpg'),
#  WindowsPath('Data/Cube/cube_42.jpg'),
#  WindowsPath('Data/Cube/cube_43.jpg'),
#  WindowsPath('Data/Cube/cube_44.jpg'),
#  WindowsPath('Data/Cube/cube_45.jpg'),
#  WindowsPath('Data/Cube/cube_46.jpg'),
#  WindowsPath('Data/Cube/cube_47.jpg'),
#  WindowsPath('Data/Cube/cube_48.jpg'),
#  WindowsPath('Data/Cube/cube_49.jpg'),
#  WindowsPath('Data/Cube/cube_5.jpg'),
#  WindowsPath('Data/Cube/cube_50.jpg'),
#  WindowsPath('Data/Cube/cube_51.jpg'),
#  WindowsPath('Data/Cube/cube_52.jpg'),
#  WindowsPath('Data/Cube/cube_6.jpg'),
#  WindowsPath('Data/Cube/cube_7.jpg'),
#  WindowsPath('Data/Cube/cube_8.jpg'),
#  WindowsPath('Data/Cube/cube_9.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_0.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_1.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_10.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_11.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_12.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_13.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_14.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_15.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_16.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_17.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_18.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_19.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_2.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_20.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_21.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_22.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_23.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_24.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_25.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_26.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_27.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_28.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_29.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_3.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_30.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_31.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_32.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_33.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_34.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_4.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_5.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_6.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_7.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_8.jpg'),
#  WindowsPath('Data/Icosahedron/icosahedron_9.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_0.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_1.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_10.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_11.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_12.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_13.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_14.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_15.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_16.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_17.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_18.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_19.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_2.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_20.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_21.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_22.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_23.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_24.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_25.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_26.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_27.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_28.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_29.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_3.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_30.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_31.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_32.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_33.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_34.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_35.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_36.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_37.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_38.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_39.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_4.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_40.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_41.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_42.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_43.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_44.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_45.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_46.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_47.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_48.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_49.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_5.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_50.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_51.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_52.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_53.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_54.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_6.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_7.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_8.jpg'),
#  WindowsPath('Data/Icosphere/icosphere_9.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_0.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_1.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_10.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_11.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_12.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_13.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_14.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_2.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_3.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_4.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_5.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_6.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_7.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_8.jpg'),
#  WindowsPath('Data/Pyramid/pyramid_9.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_0.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_1.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_10.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_11.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_12.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_13.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_14.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_15.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_16.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_17.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_18.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_19.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_2.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_20.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_21.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_22.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_23.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_24.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_25.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_26.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_27.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_28.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_29.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_3.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_30.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_31.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_32.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_33.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_34.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_35.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_36.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_37.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_38.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_39.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_4.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_40.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_41.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_42.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_43.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_44.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_45.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_46.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_47.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_48.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_49.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_5.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_50.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_51.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_52.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_53.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_54.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_55.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_56.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_57.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_58.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_59.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_6.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_60.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_61.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_62.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_63.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_64.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_65.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_66.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_67.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_68.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_69.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_7.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_70.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_71.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_72.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_73.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_74.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_75.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_76.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_77.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_78.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_79.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_8.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_80.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_81.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_82.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_83.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_84.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_85.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_86.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_87.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_88.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_89.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_9.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_90.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_91.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_92.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_93.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_94.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_95.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_96.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_97.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_98.jpg'),
#  WindowsPath('Data/Suzanne/suzanne_99.jpg'),
#  WindowsPath('Data/Torus/torus_0.jpg'),
#  WindowsPath('Data/Torus/torus_1.jpg'),
#  WindowsPath('Data/Torus/torus_10.jpg'),
#  WindowsPath('Data/Torus/torus_11.jpg'),
#  WindowsPath('Data/Torus/torus_12.jpg'),
#  WindowsPath('Data/Torus/torus_13.jpg'),
#  WindowsPath('Data/Torus/torus_14.jpg'),
#  WindowsPath('Data/Torus/torus_15.jpg'),
#  WindowsPath('Data/Torus/torus_16.jpg'),
#  WindowsPath('Data/Torus/torus_17.jpg'),
#  WindowsPath('Data/Torus/torus_18.jpg'),
#  WindowsPath('Data/Torus/torus_19.jpg'),
#  WindowsPath('Data/Torus/torus_2.jpg'),
#  WindowsPath('Data/Torus/torus_20.jpg'),
#  WindowsPath('Data/Torus/torus_21.jpg'),
#  WindowsPath('Data/Torus/torus_22.jpg'),
#  WindowsPath('Data/Torus/torus_23.jpg'),
#  WindowsPath('Data/Torus/torus_24.jpg'),
#  WindowsPath('Data/Torus/torus_25.jpg'),
#  WindowsPath('Data/Torus/torus_26.jpg'),
#  WindowsPath('Data/Torus/torus_27.jpg'),
#  WindowsPath('Data/Torus/torus_28.jpg'),
#  WindowsPath('Data/Torus/torus_29.jpg'),
#  WindowsPath('Data/Torus/torus_3.jpg'),
#  WindowsPath('Data/Torus/torus_30.jpg'),
#  WindowsPath('Data/Torus/torus_31.jpg'),
#  WindowsPath('Data/Torus/torus_32.jpg'),
#  WindowsPath('Data/Torus/torus_33.jpg'),
#  WindowsPath('Data/Torus/torus_34.jpg'),
#  WindowsPath('Data/Torus/torus_35.jpg'),
#  WindowsPath('Data/Torus/torus_36.jpg'),
#  WindowsPath('Data/Torus/torus_37.jpg'),
#  WindowsPath('Data/Torus/torus_38.jpg'),
#  WindowsPath('Data/Torus/torus_39.jpg'),
#  WindowsPath('Data/Torus/torus_4.jpg'),
#  WindowsPath('Data/Torus/torus_40.jpg'),
#  WindowsPath('Data/Torus/torus_41.jpg'),
#  WindowsPath('Data/Torus/torus_42.jpg'),
#  WindowsPath('Data/Torus/torus_43.jpg'),
#  WindowsPath('Data/Torus/torus_44.jpg'),
#  WindowsPath('Data/Torus/torus_45.jpg'),
#  WindowsPath('Data/Torus/torus_46.jpg'),
#  WindowsPath('Data/Torus/torus_47.jpg'),
#  WindowsPath('Data/Torus/torus_48.jpg'),
#  WindowsPath('Data/Torus/torus_49.jpg'),
#  WindowsPath('Data/Torus/torus_5.jpg'),
#  WindowsPath('Data/Torus/torus_50.jpg'),
#  WindowsPath('Data/Torus/torus_51.jpg'),
#  WindowsPath('Data/Torus/torus_52.jpg'),
#  WindowsPath('Data/Torus/torus_53.jpg'),
#  WindowsPath('Data/Torus/torus_54.jpg'),
#  WindowsPath('Data/Torus/torus_55.jpg'),
#  WindowsPath('Data/Torus/torus_56.jpg'),
#  WindowsPath('Data/Torus/torus_57.jpg'),
#  WindowsPath('Data/Torus/torus_6.jpg'),
#  WindowsPath('Data/Torus/torus_7.jpg'),
#  WindowsPath('Data/Torus/torus_8.jpg'),
#  WindowsPath('Data/Torus/torus_9.jpg')]

# %%
# Open a random image with PIL
imgn = Image.open(image_paths_list[42])
imgn
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
# Define the data-transformer to convert the image data into PyTorch Tensors of a specified dimension
data_transformer = transforms.Compose([
    transforms.Resize(size=(256,256)), #Resize the image to 256x256
    transforms.ToTensor()
])
# Transform the previous random image to a Tensor and visualize the reduction of the quality
Tensor_imgn = data_transformer(imgn)
plt.axis(False)
plt.imshow(Tensor_imgn.permute(1, 2, 0)) # The shape of the Tensor has to be changed as PyTorch has (C,H,W), while plt requires (H, W, C)

# %%
# Compare both next to each other:
fig, ax = plt.subplots(1,2, figsize=(10, 5))
# Original Image
ax[0].title.set_text("Original Image")
ax[0].axis(False)
ax[0].imshow(imgn)
# Reduced Image
ax[1].title.set_text("Reduced Image")
ax[1].axis(False)
ax[1].imshow(Tensor_imgn.permute(1, 2, 0))

# %%
# Create the training data
train_data = datasets.ImageFolder(root=r".\Data\Train", transform=data_transformer, target_transform=None)

# %%
# The classes of the training data are simply the folders
train_data.classes
# Out:
# ['Cube', 'Icosahedron', 'Icosphere', 'Pyramid', 'Suzanne', 'Torus']

# %%
# These classes are also assigned to indicies:
train_data.class_to_idx
# Out:
# {'Cube': 0,
#  'Icosahedron': 1,
#  'Icosphere': 2,
#  'Pyramid': 3,
#  'Suzanne': 4,
#  'Torus': 5}

# %%
# Visualize an example of the training data
plt.imshow(train_data[42][0].permute(1, 2, 0))

# %%
# Out:
# torchvision.datasets.folder.ImageFolder

# %%
# Out:
# list

# %%
train_size = 0.8

# %%
split = int(np.floor(train_size * len(data_set)))

# %%
indices = list(range(len(data_set)))

# %%
train_data = Subset(data_set, indices= indices[:split])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 train_data = Subset(data_set, indices= indices[:split])
#
# NameError: name 'Subset' is not defined
