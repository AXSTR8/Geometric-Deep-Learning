# %%
import torch
import torch.nn as nn
import numpy as np
from torchvision import transforms
from PIL import Image

# %%
#img = Image.open(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_render_2.png")
#img.save(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_test.jpg")
#img2 = Image.open(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_1.jpg")
img3 = Image.open(r"./Data\Ico\icosphere_22.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 #img = Image.open(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_render_2.png")
#       2 #img.save(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_test.jpg")
#       3 #img2 = Image.open(r"C:\Users\AlexS\OneDrive\Desktop\Test\Blender-Suzanne\suzanne_1.jpg")
# ----> 4 img3 = Image.open(r"./Data\Ico\icosphere_22.jpg")
#
# File c:\Users\AlexS\anaconda3\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data\\Ico\\icosphere_22.jpg'

# %%
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
convert_tensor = transforms.ToTensor()
img3_tensor = convert_tensor(img3)

# %%
convert_tensor = transforms.ToTensor()
img2_tensor = convert_tensor(img2)

# %%
img3_tensor.shape
# Out:
# torch.Size([3, 1080, 1920])

# %%
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
import requests
import zipfile
from pathlib import Path

# %%
data_path = Path("data/")
image_path = data_path / "image_name"

if image_path.is_dir():
    print(f"{image_path} directory already exists.")
else:
    print(f"{image_path} does not exist")
    image_path.mkdir(parents=True, exist_ok=True)

with open(data_path / "data.zip", "wb") as f:
    request = requests.get()
    f.write(request.content)
# Out:
# data\image_name does not exist
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       8     image_path.mkdir(parents=True, exist_ok=True)
#      10 with open(data_path / "data.zip", "wb") as f:
# ---> 11     request = requests.get()
#      12     f.write(request.content)
#
# TypeError: get() missing 1 required positional argument: 'url'

# %% [markdown]
# import os

# %%
import os

# %%
def walk_through_dir(dir_path):
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img3_as_array = np.asarray(img3)

# %%
img3_as_array.shape
# Out:
# (1080, 1920, 3)

# %%
img3_tensor.shape
# Out:
# torch.Size([3, 1080, 1920])

# %%
plt.imshow(img3_as_array)

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
data_transform = transforms.Compose([
    #Resize the image to 128x128
    transforms.Resize(size=(256,256)),
    #Flip the images randomly on the horizontal
    #transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# %%
img3_small_tensor = data_transform(img3)

# %%
img3_small_tensor.shape
# Out:
# torch.Size([3, 224, 224])

# %%
plt.imshow(img3_small_tensor.permute(1, 2, 0))

# %%
data_path = Path(r"./Data")

# %%
image_path_list = list(data_path.glob("*\*.jpg"))

# %%
len(image_path_list)
# Out:
# 155

# %%
imgn = Image.open(image_path_list[69])
imgn_small_tensor = data_transform(imgn)
plt.imshow(imgn_small_tensor.permute(1, 2, 0))

# %%
imgn
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
image_class = image_path_list[0].parent.stem
image_class
# Out:
# 'Ico'
